# %% [markdown]
# <a href="https://colab.research.google.com/github/yelle15/fuelcast/blob/main/GasModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
print("Hello Sam, Dreame, and Arielle.")
# Out:
# Hello Sam, Dreame, and Arielle.
